# %% [markdown]
# <a href="https://colab.research.google.com/github/KrushnaKale1999/krushna-kale/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
#sns.scatterplot()
#sns.boxplot()
#sns.catplot()
#sns.joinplot()
#sns.pairplot()

# %%
fmri = sns.load_dataset('fmri')

# %%
sns.lineplot(x=fmri.timepoint , y=fmri.signal)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.boxplot(x=titanic.pclass,y=titanic.age)
sns.boxplot(x=titanic.pclass,y=titanic.fare)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
diamond = sns.load_dataset("diamonds")

# %%
sns.histplot(diamond['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x=iris.sepal_length,y=iris.sepal_width , data=iris , hue='species')

# %%
flight =sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
